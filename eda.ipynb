# %%
import json
import os

with open("All/2023/202300000", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
ab_data = data["abstracts-retrieval-response"]

# %% [markdown]
# **General data**
# 1. item
# 2. affiliation
# 3. coredata
# 4. idxterms
# 5. language
# 6. authkeywords
# 7. subject-areas
# 8. authors

# %%
item = ab_data["item"]

item["ait:process-info"] 
# status and date

item["xocs:meta"] 
# funding list

item["bibrecord"]["head"]
# author-group, citation-title, abstracts, correspondence, citation-info, source, enhancement, grantlist

item["bibrecord"]["item-info"] 
# copyright, external-source, dbcollection, history, itemidlist

item["bibrecord"]["tail"]["bibliography"]["reference"]
# reference
# Out:
# [{'ref-fulltext': 'Zhang, Y., Jiang, J., Li, M., Gao, P., Zhou, Y., Zhang, G., Shuang, S., Dong, C., Colorimetric sensor for cysteine in human urine based on novel gold nanoparticles. Talanta. 161 (2016), 520–527.',
#   '@reference-instance-id': 'OB2BibRecID-950622316-3a2b8c99e57cfbf7cd445284e54b8133-1',
#   '@id': '1',
#   'ref-info': {'ref-publicationyear': {'@first': '2016'},
#    'ref-title': {'ref-titletext': 'Colorimetric sensor for cysteine in human urine based on novel gold nanoparticles'},
#    'refd-itemidlist': {'itemid': [{'$': 'bb0005', '@idtype': 'FRAGMENTID'},
#      {'$': '84986550772', '@idtype': 'SGR'}]},
#    'ref-volisspag': {'voliss': {'@volume': '161'},
#     'pagerange': {'@first': '520', '@last': '527'}},
#    'ref-authors': {'author': [{'@seq': '1',
#       'ce:initials': 'Y.',
#       '@_fa': 'true',
#       'ce:surname': 'Zhang',
#       'ce:indexed-name': 'Zhang Y.'},
#      {'@seq': '2',
#       'ce:initials': 'J.',
#       '@_fa': 'true',
# ...

# %%
aff = ab_data["affiliation"]
# affiliation
# Out:
# [{'affiliation-city': 'Bangkok',
#   '@id': '60091507',
#   'affilname': 'Metallurgy and Materials Research Institute Chulalongkorn University',
#   '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60091507',
#   'affiliation-country': 'Thailand'},
#  {'affiliation-city': 'Bangkok',
#   '@id': '60028190',
#   'affilname': 'Chulalongkorn University',
#   '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60028190',
#   'affiliation-country': 'Thailand'},
#  {'affiliation-city': 'Nakhon Pathom',
#   '@id': '60009499',
#   'affilname': 'Institute of Molecular Biosciences, Mahidol University',
#   '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60009499',
#   'affiliation-country': 'Thailand'}]

# %%
core = ab_data["coredata"]
# core

# %%
ab_data["idxterms"]
# index terms
# Out:
# {'mainterm': [{'$': 'Alginate hydrogels', '@weight': 'b', '@candidate': 'n'},
#   {'$': 'Alzheimers disease', '@weight': 'b', '@candidate': 'n'},
#   {'$': 'Colorimetric sensors', '@weight': 'b', '@candidate': 'n'},
#   {'$': 'Disease screening', '@weight': 'b', '@candidate': 'n'},
#   {'$': 'Graphene oxides', '@weight': 'b', '@candidate': 'n'},
#   {'$': 'Hydrogel colorimetric sensor', '@weight': 'b', '@candidate': 'n'},
#   {'$': 'Indicator displacement assays', '@weight': 'b', '@candidate': 'n'},
#   {'$': 'PV/cu2+-GO/alg hydrogel', '@weight': 'b', '@candidate': 'n'},
#   {'$': 'Pyrocatechol violet', '@weight': 'b', '@candidate': 'n'},
#   {'$': 'Urinary cysteine', '@weight': 'b', '@candidate': 'n'}]}

# %%
ab_data["language"]
# Out:
# {'@xml:lang': 'eng'}

# %%
ab_data["authkeywords"]
# Out:
# {'author-keyword': [{'@_fa': 'true', '$': "Alzheimer's disease"},
#   {'@_fa': 'true', '$': 'Hydrogel colorimetric sensor'},
#   {'@_fa': 'true', '$': 'indicator-displacement assay'},
#   {'@_fa': 'true', '$': 'PV/Cu2+-GO/Alg hydrogel'},
#   {'@_fa': 'true', '$': 'Urinary cysteine'}]}

# %%
ab_data["subject-areas"]
# Out:
# {'subject-area': [{'@_fa': 'true',
#    '$': 'Structural Biology',
#    '@code': '1315',
#    '@abbrev': 'BIOC'},
#   {'@_fa': 'true', '$': 'Biochemistry', '@code': '1303', '@abbrev': 'BIOC'},
#   {'@_fa': 'true',
#    '$': 'Molecular Biology',
#    '@code': '1312',
#    '@abbrev': 'BIOC'}]}

# %%
ab_data["authors"]
# Out:
# {'author': [{'ce:given-name': 'Siraprapa',
#    'preferred-name': {'ce:given-name': 'Siraprapa',
#     'ce:initials': 'S.',
#     'ce:surname': 'Boobphahom',
#     'ce:indexed-name': 'Boobphahom S.'},
#    '@seq': '1',
#    'ce:initials': 'S.',
#    '@_fa': 'true',
#    'affiliation': [{'@id': '60091507',
#      '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60091507'},
#     {'@id': '60009499',
#      '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60009499'}],
#    'ce:surname': 'Boobphahom',
#    '@auid': '57204796013',
#    'author-url': 'https://api.elsevier.com/content/author/author_id/57204796013',
#    'ce:indexed-name': 'Boobphahom S.'},
#   {'ce:given-name': 'Nadnudda',
#    'preferred-name': {'ce:given-name': 'Nadnudda',
#     'ce:initials': 'N.',
#     'ce:surname': 'Rodthongkum',
#     'ce:indexed-name': 'Rodthongkum N.'},
#    '@seq': '2',
#    'ce:initials': 'N.',
#    '@_fa': 'true',
# ...
